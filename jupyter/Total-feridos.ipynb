# %%
# Importando as bibliotecas necessárias e criando o dataframe:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable

data = pd.read_csv("AccidentsPortugues.csv")

# %%
# Qual a BR com mais acidentes com vítimas feridas?

# Filtrar e contar acidentes com feridos
acidentes_feridos = data[data['feridos'] > 0]
acidentes_feridos_br = acidentes_feridos['br'].astype(str).str.split('.').str[0].value_counts().nlargest(10)

# Cálculo dos percentuais
total = acidentes_feridos_br.sum()
porcentagens = (acidentes_feridos_br / total * 100).round(1)
# Normalização para as cores
norm = plt.Normalize(acidentes_feridos_br.min(), acidentes_feridos_br.max())
cores = plt.cm.coolwarm(norm(acidentes_feridos_br))
# Plotagem
plt.figure(figsize=(12, 6))
bars = plt.bar(acidentes_feridos_br.index.astype(str), acidentes_feridos_br, color=cores)
for bar, valor, pct in zip(bars, acidentes_feridos_br, porcentagens):
    plt.text(bar.get_x() + bar.get_width()/2,
             1000,
             f'{valor}\n({pct}%)',
             ha='center',
             va='bottom',
             fontsize=9,
             color='white')
plt.title('BRs com mais vítimas feridas')
plt.xlabel('BR')
plt.ylabel('Acidentes com vítimas feridas')
plt.xticks(rotation=0)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Qual UF tem mais acidentes com feridos?

# Filtrar e contar acidentes com feridos por UF
acidentes_feridos_uf = acidentes_feridos["uf"].value_counts().nlargest(10)
# Cálculo dos percentuais
total = acidentes_feridos_uf.sum()
porcentagens = (acidentes_feridos_uf / total * 100).round(1)
# Normalização para as cores
norm = plt.Normalize(acidentes_feridos_uf.min(), acidentes_feridos_uf.max())
cores = plt.cm.coolwarm(norm(acidentes_feridos_uf))
# Plotagem
plt.figure(figsize=(12, 6))
bars = plt.bar(acidentes_feridos_uf.index.astype(str), acidentes_feridos_uf, color=cores)
for bar, valor, pct in zip(bars, acidentes_feridos_uf, porcentagens):
    plt.text(bar.get_x() + bar.get_width()/2,
             500,
             f'{valor}\n({pct}%)',
             ha='center',
             va='bottom',
             fontsize=9,
             color='white')
plt.title('BRs com mais acidentes com vítimas feridas')
plt.xlabel('BR')
plt.ylabel('Acidentes com mais vítimas feridas')
plt.xticks(rotation=0)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Qual dia da semana tem mais acidentes com feridos?
acidentes_feridos_dia_semana = acidentes_feridos["dia_semana"].value_counts().nlargest(10)

# Cálculo dos percentuais
total = acidentes_feridos_dia_semana.sum()
porcentagens = (acidentes_feridos_dia_semana / total * 100).round(1)
# Normalização para as cores
norm = plt.Normalize(acidentes_feridos_dia_semana.min(), acidentes_feridos_dia_semana.max())
cores = plt.cm.coolwarm(norm(acidentes_feridos_dia_semana))
# Plotagem
plt.figure(figsize=(12, 6))
bars = plt.bar(acidentes_feridos_dia_semana.index.astype(str), acidentes_feridos_dia_semana, color=cores)
for bar, valor, pct in zip(bars, acidentes_feridos_dia_semana, porcentagens):
    plt.text(bar.get_x() + bar.get_width()/2,
             1000,
             f'{valor}\n({pct}%)',
             ha='center',
             va='bottom',
             fontsize=9,
             color='white')
# Plotagem
plt.title('Mortes por dia da semana')
plt.xlabel('')
plt.ylabel('Número de Mortes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Qual o tipo de acidente mais mortes?
tipo_acidentes_feridos = acidentes_feridos["tipo_acidente"].value_counts().nlargest(10)

# Cálculo dos percentuais
total = tipo_acidentes_feridos.sum()
porcentagens = (tipo_acidentes_feridos / total * 100).round(1)
# Normalização para as cores
norm = plt.Normalize(tipo_acidentes_feridos.min(), tipo_acidentes_feridos.max())
cores = plt.cm.coolwarm(norm(tipo_acidentes_feridos))
# Plotagem
plt.figure(figsize=(12, 6))
bars = plt.bar(tipo_acidentes_feridos.index.astype(str), tipo_acidentes_feridos, color=cores)
for bar, valor, pct in zip(bars, tipo_acidentes_feridos, porcentagens):
    plt.text(bar.get_x() + bar.get_width()/2,
             2000,
             f'{valor}\n({pct}%)',
             ha='center',
             va='bottom',
             fontsize=9,
             color='white')
plt.title('Acidentes por Tipo')
plt.xlabel('Tipo de Acidente')
plt.ylabel('Número de Mortes')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Qual a causa de acidente mais comum em acidentes com feridos?
causa_acidentes_feridos = acidentes_feridos["causa_acidente"].value_counts().nlargest(10)

# Cálculo dos percentuais
total = causa_acidentes_feridos.sum()
porcentagens = (causa_acidentes_feridos / total * 100).round(1)
# Normalização para as cores
norm = plt.Normalize(causa_acidentes_feridos.min(), causa_acidentes_feridos.max())
cores = plt.cm.coolwarm(norm(causa_acidentes_feridos))
# Plotagem
plt.figure(figsize=(12, 6))
bars = plt.bar(causa_acidentes_feridos.index.astype(str), causa_acidentes_feridos, color=cores)
for bar, valor, pct in zip(bars, causa_acidentes_feridos, porcentagens):
    plt.text(bar.get_x() + bar.get_width()/2,
             35000,
             f'{valor}\n({pct}%)',
             ha='center',
             va='bottom',
             fontsize=9,
             color='black')
plt.title('Acidentes por Causa')
plt.xlabel('Causa do Acidente')
plt.ylabel('Número de Mortes')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Total de acidentes com feridos por ano?
acidentes_feridos_acumulado_mes = pd.to_datetime(acidentes_feridos['data_inversa']).dt.month.value_counts().sort_values(ascending=False)

# Cálculo dos percentuais
total = acidentes_feridos_acumulado_mes.sum()
porcentagens = (acidentes_feridos_acumulado_mes / total * 100).round(1)
# Normalização para as cores
norm = plt.Normalize(acidentes_feridos_acumulado_mes.min(), acidentes_feridos_acumulado_mes.max())
cores = plt.cm.coolwarm(norm(acidentes_feridos_acumulado_mes))
# Plotagem
plt.figure(figsize=(12, 6))
bars = plt.bar(acidentes_feridos_acumulado_mes.index.astype(str), acidentes_feridos_acumulado_mes, color=cores)
for bar, valor, pct in zip(bars, acidentes_feridos_acumulado_mes, porcentagens):
    plt.text(bar.get_x() + bar.get_width()/2,
             1000,
             f'{valor}\n({pct}%)',
             ha='center',
             va='bottom',
             fontsize=9,
             color='black')
plt.title('Acidentes por Mês (Acumulado)')
plt.xlabel('Acumulado por mês do ano (2017 - 2023)')
plt.ylabel('Número de Acidentes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
acidentes_feridos_acumulado_dia = pd.to_datetime(acidentes_feridos['data_inversa']).dt.day.value_counts().sort_index().nlargest(15)

# Cálculo dos percentuais
total = acidentes_feridos_acumulado_dia.sum()
porcentagens = (acidentes_feridos_acumulado_dia / total * 100).round(1)
# Normalização para as cores
norm = plt.Normalize(acidentes_feridos_acumulado_dia.min(), acidentes_feridos_acumulado_dia.max())
cores = plt.cm.coolwarm(norm(acidentes_feridos_acumulado_dia))
# Plotagem
plt.figure(figsize=(12, 6))
bars = plt.bar(acidentes_feridos_acumulado_dia.index.astype(str), acidentes_feridos_acumulado_dia, color=cores)
for bar, valor, pct in zip(bars, acidentes_feridos_acumulado_dia, porcentagens):
    plt.text(bar.get_x() + bar.get_width()/2,
             100,
             f'{valor}\n({pct}%)',
             ha='center',
             va='bottom',
             fontsize=9,
             color='black')
plt.title('Acidentes por Dia (Acumulado)')
plt.xlabel('Acumulado por dias do mês (2017 - 2023)')
plt.ylabel('Número de Acidentes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
acidentes_feridos_veiculos = acidentes_feridos['veiculos'].value_counts().sort_index().nlargest(5)

# Cálculo dos percentuais
total = acidentes_feridos_veiculos.sum()
porcentagens = (acidentes_feridos_veiculos / total * 100).round(1)
# Normalização para as cores
norm = plt.Normalize(acidentes_feridos_veiculos.min(), acidentes_feridos_veiculos.max())
cores = plt.cm.coolwarm(norm(acidentes_feridos_veiculos))
# Plotagem
plt.figure(figsize=(12, 6))
bars = plt.bar(acidentes_feridos_veiculos.index.astype(str), acidentes_feridos_veiculos, color=cores)
for bar, valor, pct in zip(bars, acidentes_feridos_veiculos, porcentagens):
    plt.text(bar.get_x() + bar.get_width()/2,
             7000,
             f'{valor}\n({pct}%)',
             ha='center',
             va='bottom',
             fontsize=9,
             color='black')
plt.title('Mortes por quantidade de veículos (Acumulado)')
plt.xlabel('Quantidade de veículos envolvidos')
plt.ylabel('Número de Mortes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
