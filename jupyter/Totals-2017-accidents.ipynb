# %% [markdown]
# ### Com o ETL pronto, algumas perguntas surgem e a melhor forma de respondê-las é utilizando gráficos!

# %%
# Importando as bibliotecas necessárias e criando o dataframe:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable

data = pd.read_csv("AccidentsPortugues.csv")

# %%
data['data_inversa'] = pd.to_datetime(data['data_inversa'])

data_2017 = data[data['data_inversa'].dt.year == 2017].copy()

# %%
# Qual a BR com mais acidentes?
data_2017['br'] = data_2017['br'].astype(str).str.split('.').str[0]
acidentes_br = data_2017['br'].value_counts().nlargest(10)

# Normalização
norm = plt.Normalize(acidentes_br.min(), acidentes_br.max())
cores = plt.cm.coolwarm(norm(acidentes_br))  # Gradiente azul → vermelho

# Plotagem
plt.figure(figsize=(10, 6))
plt.bar(acidentes_br.index.astype(str), acidentes_br, color=cores)
plt.title('Acidentes por BR')
plt.xlabel('BR')
plt.ylabel('Número de Acidentes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Quantos acidentes têm vítimas feridas, fatais ou não possui vítimas?
class_acidente = data_2017["classificacao_acidente"].value_counts().nlargest(10)

# Normalização
norm = plt.Normalize(class_acidente.min(), class_acidente.max())
cores = plt.cm.coolwarm(norm(class_acidente))  # Gradiente azul → vermelho

# Plotagem
plt.figure(figsize=(10, 6))
plt.bar(class_acidente.index.astype(str), class_acidente, color=cores)
plt.title('Acidentes por Classe')
plt.xlabel('Classe')
plt.ylabel('Número de Acidentes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Qual UF tem mais acidentes?
acidentes_uf = data_2017["uf"].value_counts().nlargest(10)

# Normalização
norm = plt.Normalize(acidentes_uf.min(), acidentes_uf.max())
cores = plt.cm.coolwarm(norm(acidentes_uf))  # Gradiente azul → vermelho

# Plotagem
plt.figure(figsize=(10, 6))
plt.bar(acidentes_uf.index.astype(str), acidentes_uf, color=cores)
plt.title('Acidentes por Estado')
plt.xlabel('Estado')
plt.ylabel('Número de Acidentes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Qual dia da semana tem mais acidentes?
acidentes_dia_semana = data_2017["dia_semana"].value_counts().nlargest(10)

# Normalização
norm = plt.Normalize(acidentes_dia_semana.min(), acidentes_dia_semana.max())
cores = plt.cm.coolwarm(norm(acidentes_dia_semana))  # Gradiente azul → vermelho

# Plotagem
plt.figure(figsize=(10, 6))
plt.bar(acidentes_dia_semana.index.astype(str), acidentes_dia_semana, color=cores)
plt.title('Acidentes por dia da semana')
plt.xlabel('Dia da semana')
plt.ylabel('Número de Acidentes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Qual o tipo de acidente mais comum?
tipo_acidente = data_2017["tipo_acidente"].value_counts().nlargest(10)

# Normalização
norm = plt.Normalize(tipo_acidente.min(), tipo_acidente.max())
cores = plt.cm.coolwarm(norm(tipo_acidente))  # Gradiente azul → vermelho

# Plotagem
plt.figure(figsize=(10, 6))
plt.bar(tipo_acidente.index.astype(str), tipo_acidente, color=cores)
plt.title('Acidentes por Tipo')
plt.xlabel('Tipo de Acidente')
plt.ylabel('Número de Acidentes')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Qual a causa de acidente mais comum?
causa_acidente = data_2017["causa_acidente"].value_counts().nlargest(10)

# Normalização
norm = plt.Normalize(causa_acidente.min(), causa_acidente.max())
cores = plt.cm.coolwarm(norm(causa_acidente))  # Gradiente azul → vermelho

# Plotagem
plt.figure(figsize=(10, 8))
plt.bar(causa_acidente.index.astype(str), causa_acidente, color=cores)
plt.title('Acidentes por Causa')
plt.xlabel('Causa do Acidente')
plt.ylabel('Número de Acidentes')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
acidentes_por_mes = data_2017['data_inversa'].dt.month.value_counts().sort_index()

# Normalização
norm = plt.Normalize(acidentes_por_mes.min(), acidentes_por_mes.max())
cores = plt.cm.coolwarm(norm(acidentes_por_mes))  # Gradiente azul → vermelho

# Plotagem
plt.figure(figsize=(10, 8))
plt.bar(acidentes_por_mes.index.astype(str), acidentes_por_mes, color=cores)
plt.title('Acidentes por Mês')
plt.xlabel('Mês do Acidente')
plt.ylabel('Número de Acidentes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
acidentes_por_dia = data_2017['data_inversa'].dt.day.value_counts().sort_index()

# Normalização
norm = plt.Normalize(acidentes_por_dia.min(), acidentes_por_dia.max())
cores = plt.cm.coolwarm(norm(acidentes_por_dia))  # Gradiente azul → vermelho

# Plotagem
plt.figure(figsize=(10, 8))
plt.bar(acidentes_por_dia.index.astype(str), acidentes_por_dia, color=cores)
plt.title('Acidentes por Dia')
plt.xlabel('Dia do Acidente')
plt.ylabel('Número de Acidentes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
